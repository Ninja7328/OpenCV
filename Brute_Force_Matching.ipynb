# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninja7328/OpenCV/blob/main/Brute_Force_Matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

# %%
#Load the Image
img1=cv2.imread('Trial.jpg',0)
img2=cv2.imread('img2.jpg',0)

# %%
#Initialize the ORB detector
orb= cv2.ORB_create()

# %%
#Find the keypoints and descriptors with ORB
keypoints1,descriptors1=orb.detectAndCompute(img1,None)
keypoints2,descriptors2=orb.detectAndCompute(img2,None)

# %%
#Create a BFMatches object
bf=cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# %%
#Match descriptors
matches=bf.match(descriptors1,descriptors2)

# %%
#Sort them in ascending order of distance
matches=sorted(matches, key=lambda x:x.distance)

# %%
#Draw the first 10 matches
matched_img=cv2.drawMatches(img1,keypoints1,img2,keypoints2,matches[:10],None,flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# %%
#Display the matches
from google.colab.patches import cv2_imshow
cv2_imshow(matched_img)
# Out:
# <PIL.Image.Image image mode=RGB size=2574x1080>
